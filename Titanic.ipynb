# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
rows, columns = df.shape
print(f"The dataset has {rows} rows amd {columns} columns ")
# Out:
# The dataset has 891 rows amd 12 columns

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].fillna(value = df['Age'].median(), inplace=True)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.histplot (x=df["Age"], label="Age", bins=10, kde=True)
plt.xlabel (" Age in years")
plt.ylabel ("Density ( count)")
plt.title ("age distribution")
plt.legend()
plt.show()

# %%
sns.histplot(x=df["Sex"], label="Gender")
plt.xlabel("Passangers gender")
plt.ylabel("Density count)")
plt.title("Gender distribution")
plt.legend()
plt.show()

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=df);

# %%
sns.catplot(x='Survived', col='Embarked', kind='count',
data=df);

# %%
sns.catplot(x='Survived', col='Pclass', kind='count', data=df);

# %%
sns.catplot(x='Survived', col='Parch', kind='count', data=df);

# %%
sns.catplot(x='Survived', col='SibSp', kind='count', data=df);

# %%
sns.FacetGrid(df, hue="Survived") \
 .map(sns.histplot, "Parch") \
 .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="Survived") \
 .map(sns.histplot, "Embarked") \
 .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="Survived") \
 .map(sns.histplot, "Pclass") \
 .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="Survived") \
 .map(sns.histplot, "SibSp") \
 .add_legend();
plt.show();

# %%
sns.boxplot(x="Survived", y="Age", data=df)
plt.title("Box Plot of age")
plt.xlabel("Survival Status")
plt.ylabel("Age")
plt.show()
sns.boxplot(x="Survived", y="Parch", data=df)
plt.title("Box Plot of Parch")
plt.xlabel("Survival Status")
plt.ylabel("Parch")
plt.show()
sns.boxplot(x="Survived", y="Fare", data=df)
plt.title("Box Plot of Fare")
plt.xlabel("Survival Status")
plt.ylabel("Fare")
plt.show()

# %%
sns.violinplot(x="Survived", y="Age", data=df)
plt.title("Violin Plot of Age");

# %%
sns.violinplot(x="Survived", y="SibSp", data=df)
plt.title("Violin Plot of SibSp");

# %%
sns.violinplot(x="Survived", y="Parch", data=df)
plt.title("Violin Plot of Parch");

# %%
sns.violinplot(x="Survived", y="Fare", data=df)
plt.title("Violin Plot of Fare");

# %%
sns.pairplot(df[['Pclass','Age','SibSp','Parch','Fare','Survived']],hue="Survived")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Embarked']=le.fit_transform(df['Embarked'])
df["Sex"] = le. fit_transform(df['Sex'])
df=df.drop(['PassengerId','Ticket','Name','Cabin'],
axis=1)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
X=df[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
Y=df['Survived']
Y.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score , make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,
test_size=0.20,random_state=42)
x_test.shape,x_train.shape,y_test.shape,y_train.shape
# Out:
# ((179, 7), (712, 7), (179,), (712,))

# %%
knn_clf=KNeighborsClassifier()
knn_clf.fit(x_train,y_train)
y_prediction1=knn_clf.predict(x_test)
acc_knn=accuracy_score(y_test,y_prediction1)
acc_knn
# Out:
# 0.7206703910614525

# %%
clf=GaussianNB()
clf.fit(x_train,y_train)
y_prediction1=clf.predict(x_test)
acc_gnb=accuracy_score(y_test,y_prediction1)
acc_gnb
# Out:
# 0.776536312849162

# %%
dt_clf=DecisionTreeClassifier()
dt_clf.fit(x_train,y_train)
y_prediction1=dt_clf.predict(x_test)
acc_dt=accuracy_score(y_test,y_prediction1)
acc_dt
# Out:
# 0.7597765363128491

# %%
rf_clf=RandomForestClassifier()
rf_clf.fit(x_train,y_train)
y_prediction1=clf.predict(x_test)
acc_rf=accuracy_score(y_test,y_prediction1)
acc_rf
# Out:
# 0.776536312849162

# %%
model_performance = pd.DataFrame({
    "Model": ["Random Forest", 
               "K Nearest Neighbors", "Gaussian Naive Bayes",  
              "Decision Tree"],
    "Accuracy": [acc_rf, acc_knn, acc_gnb, acc_dt]
})

model_performance.sort_values(by="Accuracy", ascending=False)
# Out:
#                   Model  Accuracy
# 0         Random Forest  0.776536
# 2  Gaussian Naive Bayes  0.776536
# 3         Decision Tree  0.759777
# 1   K Nearest Neighbors  0.720670
